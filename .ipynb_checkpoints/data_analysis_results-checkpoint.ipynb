# %% [markdown]
# # Analyzing the geothermal results
# I have reduced all the simulation results to a single data file of the recovery factors and CO2 emission. In this notebook, I'm going to analyze the data.

# %%
using Dierckx, DataFrames, PyPlot, JLD, CoolProp, CSV, SetPyPlot
setrcparam()
@load "input_param.jld"
# Out:
# ┌ Info: Recompiling stale cache file /home/ali/.julia/compiled/v1.1/SetPyPlot/Rkvls.ji for SetPyPlot [d6c70c59-9b85-50b1-926c-19fb5cf24e7d]
# └ @ Base loading.jl:1184
# ┌ Warning: Package SetPyPlot does not have PyPlot in its dependencies:
# │ - If you have SetPyPlot checked out for development and have
# │   added PyPlot as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with SetPyPlot
# └ Loading PyPlot into SetPyPlot from project dependency, future warnings for SetPyPlot are suppressed.
# 16-element Array{Symbol,1}:
#  :MW_CO2
#  :MW_coal
#  :MW_gas
#  :e_igcc
#  :e_ngcc
#  :e_pc
#  :em_coal
#  :em_gas
#  :eta_driver
#  :eta_pump
#  :ex_ccs
#  :ex_coal
#  :ex_gas
#  :η_igcc
#  :η_ngcc
#  :η_pc

# %%
em_gas*1e3
# Out:
# 0.05499999999999999

# %%
df_geo = CSV.read("geothermal_final_results.csv")
# Out:
# 150×11 DataFrame. Omitted printing of 5 columns
# │ Row │ q_m3_s    │ k_m2     │ L_m      │ t_life_s  │ R_th       │ R_pr       │
# │     │ Float64⍰  │ Float64⍰ │ Float64⍰ │ Float64⍰  │ Float64⍰   │ Float64⍰   │
# ├─────┼───────────┼──────────┼──────────┼───────────┼────────────┼────────────┤
# │ 1   │ 0.0138889 │ 2.0e-14  │ 500.0    │ 1.05763e9 │ -0.310919  │ -3.78832   │
# │ 2   │ 0.0138889 │ 2.0e-14  │ 650.0    │ 1.4292e9  │ -0.417142  │ -4.2143    │
# │ 3   │ 0.0138889 │ 2.0e-14  │ 800.0    │ 1.77659e9 │ -0.523523  │ -4.63601   │
# │ 4   │ 0.0138889 │ 2.0e-14  │ 900.0    │ 2.02833e9 │ -0.60341   │ -4.95111   │
# │ 5   │ 0.0138889 │ 2.0e-14  │ 1000.0   │ 2.2559e9  │ -0.676724  │ -5.23971   │
# │ 6   │ 0.0138889 │ 5.0e-14  │ 500.0    │ 1.05763e9 │ 0.388476   │ -1.05631   │
# │ 7   │ 0.0138889 │ 5.0e-14  │ 650.0    │ 1.4292e9  │ 0.352124   │ -1.20935   │
# │ 8   │ 0.0138889 │ 5.0e-14  │ 800.0    │ 1.77659e9 │ 0.313042   │ -1.36818   │
# │ 9   │ 0.0138889 │ 5.0e-14  │ 900.0    │ 2.02833e9 │ 0.282732   │ -1.48961   │
# │ 10  │ 0.0138889 │ 5.0e-14  │ 1000.0   │ 2.2559e9  │ 0.254659   │ -1.6015    │
# ⋮
# │ 140 │ 0.0694444 │ 2.0e-13  │ 1000.0   │ 4.5118e8  │ 0.00680886 │ -2.56967   │
# │ 141 │ 0.0694444 │ 5.0e-13  │ 500.0    │ 2.11527e8 │ 0.52775    │ -0.512278  │
# │ 142 │ 0.0694444 │ 5.0e-13  │ 650.0    │ 2.85839e8 │ 0.515198   │ -0.572355  │
# │ 143 │ 0.0694444 │ 5.0e-13  │ 800.0    │ 3.55319e8 │ 0.499073   │ -0.641501  │
# │ 144 │ 0.0694444 │ 5.0e-13  │ 900.0    │ 4.05666e8 │ 0.48521    │ -0.698692  │
# │ 145 │ 0.0694444 │ 5.0e-13  │ 1000.0   │ 4.5118e8  │ 0.472416   │ -0.750886  │
# │ 146 │ 0.0694444 │ 1.0e-12  │ 500.0    │ 2.11527e8 │ 0.644284   │ -0.0570673 │
# │ 147 │ 0.0694444 │ 1.0e-12  │ 650.0    │ 2.85839e8 │ 0.643377   │ -0.0716543 │
# │ 148 │ 0.0694444 │ 1.0e-12  │ 800.0    │ 3.55319e8 │ 0.638471   │ -0.0969784 │
# │ 149 │ 0.0694444 │ 1.0e-12  │ 900.0    │ 4.05666e8 │ 0.632871   │ -0.12189   │
# │ 150 │ 0.0694444 │ 1.0e-12  │ 1000.0   │ 4.5118e8  │ 0.627619   │ -0.144626  │

# %% [markdown]
# # Sensitivity analysis

# %% [markdown]
# ## Step 1
# Find a list of permeability, well-spacing, and flow rates

# %%
flow_rates = df_geo[:q_m3_s] # [m^3/s]
k          = df_geo[:k_m2]   # [m^2]
L          = df_geo[:L_m]    # [m]
flow_range = union(flow_rates)
k_range    = union(k)
L_range    = union(L)
# Out:
# 5-element Array{Union{Missing, Float64},1}:
#   500.0
#   650.0
#   800.0
#   900.0
#  1000.0

# %%
k_range
# Out:
# 6-element Array{Union{Missing, Float64},1}:
#  2.0e-14
#  5.0e-14
#  1.0e-13
#  2.0e-13
#  5.0e-13
#  1.0e-12

# %% [markdown]
# ## Step 2
# For a fixed value of well spacing, plot the effect of perm for different flow rates, and see if the results look good:
# ### Effect of permeability

# %%
line_style = ["-", "--", "-.", ":", "-"]
i=0
for L_well in L_range
    figure(figsize=(5,3))
    xlabel("Permeability [m\$^2\$]")
    ylabel("Practical recovery factor [-]")
    i++
    for q in flow_range
        df_temp = df_geo[(df_geo[:q_m3_s].==q) .& (df_geo[:L_m].==L_well), :]
        plot(df_temp[:k_m2], df_temp[:R_pr], line_style[i], label = "q = $(q*3600) m\$^3\$/h")
    end
    legend()
    plot([0, 1e-12], [0,0], "--k")
    axis([0, 1e-12, -1,1])
    title("L = $L_well [m]")
end
# Out:
# Figure(PyObject <Figure size 1500x900 with 1 Axes>)
# Figure(PyObject <Figure size 1500x900 with 1 Axes>)
# Figure(PyObject <Figure size 1500x900 with 1 Axes>)
# Figure(PyObject <Figure size 1500x900 with 1 Axes>)
# Figure(PyObject <Figure size 1500x900 with 1 Axes>)

# %%
for L_well in L_range
    figure(figsize=(4,3))
    xlabel("Permeability [m\$^2\$]")
    ylabel("Zero-emission recovery factor [-]")
    for q in flow_range
        df_temp = df_geo[(df_geo[:q_m3_s].==q) .& (df_geo[:L_m].==L_well), :]
        plot(df_temp[:k_m2], df_temp[:R_ze], label = "q = $(q*3600) m\$^3\$/h")
#         plot(df_temp[:k_m2], df_temp[:R_pr], label = "q = $(q*3600) m\$^3\$/h")
    end
    legend()
    plot([0, 1e-12], [0,0], "--k")
    axis([0, 1e-12, -1,1])
    title("L = $L_well [m]")
end
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)

# %% [markdown]
# ### Effect of flow rate
# Change the flow rate in different well spacing in different reservoirs

# %%
for k_res in k_range
    figure(figsize=(5,3))
    xlabel("Flow rate \L[m^3/h]")
    ylabel("Practical recovery factor [-]")
    for L_well in L_range
        df_temp = df_geo[(df_geo[:k_m2].==k_res) & (df_geo[:L_m].==L_well), :]
        plot(df_temp[:q_m3_s]*3600, df_temp[:R_pr], alpha = 0.5, label = "L = $L_well [m]")
    end
    legend()
    #plot([0, 1e-12], [0,0], "--k")
    #axis([0, 1e-12, -1,1])
    title("k = $(k_res*1e12) [D]")
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec2d98ff10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec2d90d910>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec2d715190>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec2d6ef610>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec2d66b7d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec2d5e7d50>)

# %% [markdown]
# ### Effect of flow rate on the project life time
# Conclusion: project life time does not depend on the permeability of the reservoir. It is important for the project to have an acceptable lifetime to justify the capital investments.

# %%
for k_res in k_range
    figure(figsize=(4,3))
    xlabel("Flow rate [m\$^3\$/h]")
    ylabel("Project life time [year]")
    for L_well in L_range
        df_temp = df_geo[(df_geo[:k_m2].==k_res) .& (df_geo[:L_m].==L_well), :]
        plot(df_temp[:q_m3_s]*3600, df_temp[:t_life_s]/(3600*24*365), alpha = 0.8, label = "L = $L_well [m]")
    end
    legend()
    #plot([0, 1e-12], [0,0], "--k")
    #axis([0, 1e-12, -1,1])
    plot(df_geo[:q_m3_s]*3600, df_geo[:t_life_s]/(3600*24*365), "o")
    savefig("figs/project_life_time.png")
#     title("k = $(k_res*1e12) [D]")
end
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)

# %% [markdown]
# ### CO2 emission:

# %%
figure(figsize=(5,3))
plot(df_geo[:q_m3_s]*3600, df_geo[:c_CO2], alpha = 0.5, "o")
plot([0, 260], [em_gas, em_gas]*1e3, "--k")
xlabel("Flow rate [m^3/h]")
ylabel("CO2 emission [kg CO2/MJ]")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec381fa310>)
# PyObject Text(24,0.5,u'CO2 emission [kg CO2/MJ]')

# %%
df_geo.colindex
# Out:
# DataFrames.Index(Dict(:heat_per_m3=>11,:R_ze=>7,:c_CO2=>8,:k_m2=>2,:t_life_s=>4,:c_CO2_heat=>10,:COP=>9,:R_th=>5,:q_m3_s=>1,:L_m=>3…),Symbol[:q_m3_s,:k_m2,:L_m,:t_life_s,:R_th,:R_pr,:R_ze,:c_CO2,:COP,:c_CO2_heat,:heat_per_m3])

# %% [markdown]
# ## Find the optimum range
# Apply the following criteria:
#   + life time longer than 30 years
#   + positive zero-emission recovery factors
#   + lower that two times methane emission

# %%
T_c = 2.0+273.15 # [K]
T_h = 22+273.15 # [K]
COP_th = T_h/(T_h-T_c)
COP_air = 2.0 # average value (per unit electricity)
COP_geo = 5.0 # shallow heat (comes from the sun)
COP_methane = 1.0 # ignoring heat loss

t_life_crit = 30       # years
c_CO2_crit  = em_gas*1e3*2.0 # kg/MJ

u_ht = 1.0 # W/m2/K
A_ht = 4*10.0*3.0 # only surrounding walls
Q_heat = u_ht*A_ht*(T_h-T_c)/1000 # kJ/s
n_houses = 400 # number of houses to be covered by the geothermal project
m_water = Q_heat*1000*n_houses/(PropsSI("HMASS", "T", 80+273.15, "P", 1e5, "H2O")-PropsSI("HMASS", "T", 40+273.15, "P", 1e5, "H2O"))
q_water = m_water/PropsSI("D", "T", 40+273.15, "P", 1e5, "H2O") # [m3/s]

df_practical = df_geo[(df_geo[:t_life_s].>(30.0*24*3600)) & (df_geo[:R_ze].>0.0) & (df_geo[:c_CO2].<c_CO2_crit), :]
# Out:
# 30×11 DataFrames.DataFrame
# │ Row │ q_m3_s    │ k_m2    │ L_m    │ t_life_s  │ R_th     │ R_pr     │
# ├─────┼───────────┼─────────┼────────┼───────────┼──────────┼──────────┤
# │ 1   │ 0.0138889 │ 2.0e-13 │ 500.0  │ 1.05763e9 │ 0.738174 │ 0.309701 │
# │ 2   │ 0.0138889 │ 2.0e-13 │ 650.0  │ 1.4292e9  │ 0.736756 │ 0.293118 │
# │ 3   │ 0.0138889 │ 2.0e-13 │ 800.0  │ 1.77659e9 │ 0.731324 │ 0.265735 │
# │ 4   │ 0.0138889 │ 2.0e-13 │ 900.0  │ 2.02833e9 │ 0.725803 │ 0.241132 │
# │ 5   │ 0.0138889 │ 2.0e-13 │ 1000.0 │ 2.2559e9  │ 0.720351 │ 0.217613 │
# │ 6   │ 0.0138889 │ 5.0e-13 │ 500.0  │ 1.05763e9 │ 0.808113 │ 0.582902 │
# │ 7   │ 0.0138889 │ 5.0e-13 │ 650.0  │ 1.4292e9  │ 0.813683 │ 0.593612 │
# │ 8   │ 0.0138889 │ 5.0e-13 │ 800.0  │ 1.77659e9 │ 0.81498  │ 0.592518 │
# │ 9   │ 0.0138889 │ 5.0e-13 │ 900.0  │ 2.02833e9 │ 0.814418 │ 0.587281 │
# │ 10  │ 0.0138889 │ 5.0e-13 │ 1000.0 │ 2.2559e9  │ 0.813489 │ 0.581435 │
# │ 11  │ 0.0138889 │ 1.0e-12 │ 500.0  │ 1.05763e9 │ 0.831427 │ 0.673969 │
# ⋮
# │ 19  │ 0.0277778 │ 5.0e-13 │ 900.0  │ 1.01416e9 │ 0.742067 │ 0.304659 │
# │ 20  │ 0.0277778 │ 5.0e-13 │ 1000.0 │ 1.12795e9 │ 0.738151 │ 0.28714  │
# │ 23  │ 0.441867  │ 0.0219585 │ 21.4071 │ 0.00256924 │ 1.55628e5   │
# │ 24  │ 0.435131  │ 0.0222813 │ 21.1002 │ 0.00260662 │ 155522.0    │
# │ 25  │ 0.427817  │ 0.0226319 │ 20.7606 │ 0.00264925 │ 1.55767e5   │
# │ 26  │ 0.211165  │ 0.033016  │ 14.2827 │ 0.00385082 │ 154389.0    │
# │ 27  │ 0.21413   │ 0.032874  │ 14.3216 │ 0.00384036 │ 1.54994e5   │
# │ 28  │ 0.202501  │ 0.0334313 │ 14.0605 │ 0.00391168 │ 1.55634e5   │
# │ 29  │ 0.18745   │ 0.0341527 │ 13.7656 │ 0.00399547 │ 155528.0    │
# │ 30  │ 0.172841  │ 0.0348529 │ 13.4808 │ 0.00407987 │ 155773.0    │

# %%
flow_rates_pr = df_practical[:q_m3_s] # [m^3/s]
k_pr          = df_practical[:k_m2]   # [m^2]
L_pr          = df_practical[:L_m]    # [m]
flow_range_pr = union(flow_rates_pr)
k_range_pr    = union(k_pr)
L_range_pr    = union(L_pr)
# Out:
# 5-element Array{Float64,1}:
#   500.0
#   650.0
#   800.0
#   900.0
#  1000.0

# %%
k_range_pr
# Out:
# 3-element Array{Float64,1}:
#  2.0e-13
#  5.0e-13
#  1.0e-12

# %%
figure(figsize=(5,3))
plot(df_practical[:q_m3_s]*3600, df_practical[:c_CO2], alpha = 0.5, "o")
plot([0, 260], [em_gas, em_gas]*1e3, "--k")
xlabel("Flow rate [m^3/h]")
ylabel("CO2 emission [kg CO2/MJ]")
tight_layout()
savefig("carbon_emission_geothermal.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec2d40d1d0>)

# %% [markdown]
# ## Compare with the current state of technology
# The theoretical COP can be calculated based on the temperature of the outside (temperature outside of the house, where heat is extracted) and the desirable temperature inside (where heat is delivered). It is calculated by
# $$COP_{th} = \frac{T_h}{T_h-T_c}$$

# %% [markdown]
# ## compare with a methane burner
# Find cases with a COP less than 1.0

# %%
df_current = df_geo[df_geo[:COP].<1.0, :]
# Out:
# 29×11 DataFrames.DataFrame
# │ Row │ q_m3_s    │ k_m2    │ L_m    │ t_life_s  │ R_th     │ R_pr     │
# ├─────┼───────────┼─────────┼────────┼───────────┼──────────┼──────────┤
# │ 1   │ 0.0277778 │ 2.0e-14 │ 500.0  │ 5.28817e8 │ -1.4896  │ -8.39255 │
# │ 2   │ 0.0277778 │ 2.0e-14 │ 650.0  │ 7.14598e8 │ -1.71221 │ -9.27316 │
# │ 3   │ 0.0277778 │ 2.0e-14 │ 800.0  │ 8.88297e8 │ -1.9307  │ -10.1328 │
# │ 4   │ 0.0277778 │ 2.0e-14 │ 900.0  │ 1.01416e9 │ -2.09324 │ -10.7707 │
# │ 5   │ 0.0277778 │ 2.0e-14 │ 1000.0 │ 1.12795e9 │ -2.24194 │ -11.3538 │
# │ 6   │ 0.0416667 │ 2.0e-14 │ 500.0  │ 3.52545e8 │ -2.67527 │ -13.0241 │
# │ 8   │ -20.2096 │ 1.01179  │ 0.464582 │ 0.118386   │ 1.55634e5   │
# │ 9   │ -21.4347 │ 1.07051  │ 0.439168 │ 0.125237   │ 155528.0    │
# │ 10  │ -22.5535 │ 1.12413  │ 0.417963 │ 0.131591   │ 155773.0    │
# │ 11  │ -22.7909 │ 1.13551  │ 0.415279 │ 0.132441   │ 1.54393e5   │
# ⋮
# │ 18  │ -11.2709 │ 0.583356 │ 0.805904 │ 0.0682463  │ 1.55531e5   │
# │ 19  │ -11.8637 │ 0.611766 │ 0.768011 │ 0.0716136  │ 1.55776e5   │
# │ 20  │ -28.7596 │ 1.42159  │ 0.331706 │ 0.165809   │ 1.54395e5   │
# │ 21  │ -31.6202 │ 1.5587   │ 0.302047 │ 0.182091   │ 1.54999e5   │
# │ 22  │ -34.3902 │ 1.69147  │ 0.277897 │ 0.197915   │ 1.55639e5   │
# │ 23  │ -36.4386 │ 1.78965  │ 0.262692 │ 0.20937    │ 1.55533e5   │
# │ 24  │ -38.308  │ 1.87925  │ 0.250015 │ 0.219987   │ 1.55778e5   │
# │ 25  │ -11.3477 │ 0.587038 │ 0.803271 │ 0.0684701  │ 1.54395e5   │
# │ 26  │ -12.4683 │ 0.640748 │ 0.734766 │ 0.0748537  │ 1.54999e5   │
# │ 27  │ -13.5622 │ 0.693177 │ 0.678116 │ 0.0811071  │ 1.55639e5   │
# │ 28  │ -14.3759 │ 0.732179 │ 0.642093 │ 0.0856574  │ 1.55533e5   │
# │ 29  │ -15.1185 │ 0.767773 │ 0.611953 │ 0.0898762  │ 1.55778e5   │

# %% [markdown]
# :MW_CO2
#  :MW_coal
#  :MW_gas
#  :e_igcc
#  :e_ngcc
#  :e_pc
#  :em_coal
#  :em_gas
#  :eta_driver
#  :eta_pump
#  :ex_ccs
#  :ex_coal
#  :ex_gas
#  :η_igcc
#  :η_ngcc
#  :η_pc

# %%
figure(figsize=(5,3))
plot(df_geo[:k_m2]*1e12, df_geo[:COP], "o", alpha = 0.5)
plot([0,1.1], [1.0, 1.0], "--k", label = "methane")
plot([0,1.1], [2.0, 2.0], "-r", label = "heat pump")
plot([0,1.1], [5.0, 5.0], ":g", label = "geo heat pump")
axis([0,1.05,0,40])
legend()
ylabel("COP")
xlabel("Permeability [D]")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fec381fa3d0>)
# PyObject Text(0.5,24,u'Permeability [D]')

# %%
figure(figsize=(5,3))
semilogy(df_geo[:k_m2]*1e12, df_geo[:COP], "o", alpha = 0.5)
semilogy([0,1.1], [0.8, 0.8], "--k", label = "methane")
semilogy([0,1.1], [1.0, 1.0], "-r", label = "heat pump")
semilogy([0,1.1], [2.0, 2.0], ":g", label = "geo heat pump")
axis([0,1.05,0,40])
legend()
ylabel("COP")
xlabel("Permeability [D]")
# Out:
# Figure(PyObject <Figure size 1500x900 with 1 Axes>)
# PyObject Text(0.5, 66.0, 'Permeability [D]')
